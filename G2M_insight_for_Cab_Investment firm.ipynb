# %% [markdown]
# ## 1. Import Libraries

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

warnings.filterwarnings("ignore")

# %%
cab_df = pd.read_csv('/Users/sharonokech/Documents/Data_Glacier_Virtual_Internship/My_Tasks/DataSets/Cab_Data.csv')
cab_df.head(10)
#'/Users/sharonokech/Documents/Data_Glacier_Virtual_Internship/My_Tasks/DataSets/Cab_Data.csv'
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
# 5        10000016     2016-01-07  Pink Cab  ATLANTA GA          6.06
# 6        10000017     2016-01-03  Pink Cab   AUSTIN TX         44.00
# 7        10000018     2016-01-07  Pink Cab   AUSTIN TX         35.65
# 8        10000019     2016-01-12  Pink Cab   BOSTON MA         14.40
# 9        10000020     2016-01-06  Pink Cab   BOSTON MA         10.89
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776
# 5          72.43        63.024
# 6         576.15       475.200
# 7         466.10       377.890
# 8         191.61       146.880
# 9         156.98       113.256

# %%
#cabc_df = cab_df.pivot(index='City', columns='Company' , values='Cost of Trip')

# %% [markdown]
# ## 2. Descriptive Data Analysis
# ### Consice Summary of the Data Frame

# %%
print('DataFrame shape:', cab_df.shape)

print('DataFrame size:', cab_df.size)
# Out:
# DataFrame shape: (359392, 7)
# DataFrame size: 2515744

# %%
#there no missing values due to the no null
cab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  object
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 19.2+ MB

# %%
cab_df.isnull()
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip
# 0               False         False
# 1               False         False
# 2               False         False
# 3               False         False
# 4               False         False
# ...               ...           ...
# 359387          False         False
# 359388          False         False
# 359389          False         False
# 359390          False         False
# 359391          False         False
#
# [359392 rows x 7 columns]

# %%
cab_df.sort_values(by=['Price Charged'], ascending=False)
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 138644        10170615     2017-05-05  Yellow Cab    NEW YORK NY
# 138669        10170640     2017-05-05  Yellow Cab    NEW YORK NY
# 138766        10170737     2017-04-30  Yellow Cab    NEW YORK NY
# 247599        10302893     2018-02-16  Yellow Cab  PITTSBURGH PA
# 138548        10170519     2017-04-30  Yellow Cab    NEW YORK NY
# ...                ...            ...         ...            ...
# 285213        10350487     2018-07-23    Pink Cab      DALLAS TX
# 132169        10162663     2017-04-17    Pink Cab      DALLAS TX
# 15884         10020197     2016-03-30    Pink Cab      BOSTON MA
# 246581        10301695     2018-02-20    Pink Cab  PITTSBURGH PA
# 143508        10176703     2017-05-29    Pink Cab   NASHVILLE TN
#
#         KM Travelled  Price Charged  Cost of Trip
# 138644         46.80        2048.03      584.0640
# 138669         43.29        2016.70      571.4280
# 138766         43.20        2013.95      580.6080
# 247599         47.20        1993.83      594.7200
# 138548         41.81        1981.05      556.9092
# ...              ...            ...           ...
# 285213          1.94          16.76       19.9820
# 132169          1.92          16.53       19.2000
# 15884           1.90          16.38       19.3800
# 246581          2.10          15.75       24.7800
# 143508          1.98          15.60       21.3840
#
# [359392 rows x 7 columns]

# %%
cab_df.dtypes
# Out:
# Transaction ID      int64
# Date of Travel     object
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
cab_df.head
# Out:
# <bound method NDFrame.head of         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-08    Pink Cab     ATLANTA GA
# 1             10000012     2016-01-06    Pink Cab     ATLANTA GA
# 2             10000013     2016-01-02    Pink Cab     ATLANTA GA
# 3             10000014     2016-01-07    Pink Cab     ATLANTA GA
# 4             10000015     2016-01-03    Pink Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10440101     2018-01-08  Yellow Cab  WASHINGTON DC
# 359388        10440104     2018-01-04  Yellow Cab  WASHINGTON DC
# 359389        10440105     2018-01-05  Yellow Cab  WASHINGTON DC
# 359390        10440106     2018-01-05  Yellow Cab  WASHINGTON DC
# 359391        10440107     2018-01-02  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192
#
# [359392 rows x 7 columns]>

# %%
cab_df['Date of Travel'] = pd.to_datetime(cab_df['Date of Travel'])#, format='%Y%m%d')
cab_df.dtypes
# Out:
# Transaction ID             int64
# Date of Travel    datetime64[ns]
# Company                   object
# City                      object
# KM Travelled             float64
# Price Charged            float64
# Cost of Trip             float64
# dtype: object

# %%
#factor variable in the company column: Pink Cab and Yellow Cab
cab_df['Company'].unique()
# Out:
# array(['Pink Cab', 'Yellow Cab'], dtype=object)

# %%
cab_df['City'].unique()
# Out:
# array(['ATLANTA GA', 'AUSTIN TX', 'BOSTON MA', 'CHICAGO IL', 'DALLAS TX',
#        'DENVER CO', 'LOS ANGELES CA', 'MIAMI FL', 'NASHVILLE TN',
#        'NEW YORK NY', 'ORANGE COUNTY', 'PHOENIX AZ', 'PITTSBURGH PA',
#        'SACRAMENTO CA', 'SAN DIEGO CA', 'SEATTLE WA', 'SILICON VALLEY',
#        'TUCSON AZ', 'WASHINGTON DC'], dtype=object)

# %%
cab_df.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000

# %% [markdown]
# profile = ProfileReport(cab_df,title="Cab Data Profile"
# profile.to_widgets()

# %%
Transaction_ID_df = pd.read_csv('/Users/sharonokech/Documents/Data_Glacier_Virtual_Internship/My_Tasks/DataSets/Transaction_ID.csv')
Transaction_ID_df.head(10)
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card
# 5        10000016        27318         Cash
# 6        10000017        33788         Card
# 7        10000018        34106         Card
# 8        10000019        59799         Cash
# 9        10000020        57982         Cash

# %%
print('DataFrame shape:', Transaction_ID_df.shape)

print('DataFrame size:', Transaction_ID_df.size)
# Out:
# DataFrame shape: (440098, 3)
# DataFrame size: 1320294

# %%
Transaction_ID_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
Transaction_ID_df.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %%
Transaction_ID_df.isnull()
# Out:
#         Transaction ID  Customer ID  Payment_Mode
# 0                False        False         False
# 1                False        False         False
# 2                False        False         False
# 3                False        False         False
# 4                False        False         False
# ...                ...          ...           ...
# 440093           False        False         False
# 440094           False        False         False
# 440095           False        False         False
# 440096           False        False         False
# 440097           False        False         False
#
# [440098 rows x 3 columns]

# %%
Transaction_ID_df['Payment_Mode'].unique()
# Out:
# array(['Card', 'Cash'], dtype=object)

# %%
#Change Payment_Mode to category type
Transaction_ID_df['Payment_Mode'] = Transaction_ID_df['Payment_Mode'].astype('category')
Transaction_ID_df.dtypes
# Out:
# Transaction ID       int64
# Customer ID          int64
# Payment_Mode      category
# dtype: object

# %%
#checking for duplicates in colums
Transaction_ID_df['Transaction ID'].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 440093    False
# 440094    False
# 440095    False
# 440096    False
# 440097    False
# Name: Transaction ID, Length: 440098, dtype: bool

# %%
#Customer column has duplicates implying one customer can own several transaction IDS.
Transaction_ID_df['Customer ID'].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 440093     True
# 440094     True
# 440095     True
# 440096     True
# 440097     True
# Name: Customer ID, Length: 440098, dtype: bool

# %%
#Transaction_ID_df.describe

# %%
city_df= pd.read_csv('/Users/sharonokech/Documents/Data_Glacier_Virtual_Internship/My_Tasks/DataSets/city.csv')
city_df.head(10)
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247
# 5   ORANGE COUNTY   1,030,185     12,994
# 6    SAN DIEGO CA     959,307     69,995
# 7      PHOENIX AZ     943,999      6,133
# 8       DALLAS TX     942,908     22,157
# 9      ATLANTA GA     814,885     24,701

# %%
city_df['Population'] = city_df['Population'].str.replace(',', '')
city_df['Population']= city_df['Population'].astype('int')

# %%
city_df['Users']= city_df['Users'].str.replace(',', '')
city_df['Users']= city_df['Users'].astype('int')

# %%
city_df.dtypes
# Out:
# City          object
# Population     int64
# Users          int64
# dtype: object

# %%
print('DataFrame shape:', city_df.shape)

print('DataFrame size:', city_df.size)
# Out:
# DataFrame shape: (20, 3)
# DataFrame size: 60

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     int64
#  2   Users       20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %% [markdown]
# city_df.isnull()

# %% [markdown]
# city_df['City'].unique

# %%
city_df.describe()
# Mean users are 64520
# Out:
#          Population          Users
# count  2.000000e+01      20.000000
# mean   1.231592e+06   64520.650000
# std    1.740127e+06   83499.375289
# min    2.489680e+05    3643.000000
# 25%    6.086372e+05   11633.250000
# 50%    7.845590e+05   23429.000000
# 75%    1.067041e+06   91766.000000
# max    8.405837e+06  302149.000000

# %%
#CustomerID Data
Customer_ID_df = pd.read_csv('/Users/sharonokech/Documents/Data_Glacier_Virtual_Internship/My_Tasks/DataSets/Customer_ID.csv')
Customer_ID_df.head(10)
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536
# 5        27318   Male   25               13984
# 6        33788   Male   23               23788
# 7        34106   Male   19               19980
# 8        59799   Male   33               19271
# 9        57982   Male   57                5068

# %%
print('DataFrame shape:', Customer_ID_df.shape)

print('DataFrame size:', Customer_ID_df.size)
# Out:
# DataFrame shape: (49171, 4)
# DataFrame size: 196684

# %%
Customer_ID_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
Customer_ID_df['Gender'] = Customer_ID_df['Gender'].astype('category')
Customer_ID_df.dtypes
# Out:
# Customer ID              int64
# Gender                category
# Age                      int64
# Income (USD/Month)       int64
# dtype: object

# %%
Customer_ID_df['Customer ID'].unique
# Out:
# <bound method Series.unique of 0        29290
# 1        27703
# 2        28712
# 3        28020
# 4        27182
#          ...
# 49166    12490
# 49167    14971
# 49168    41414
# 49169    41677
# 49170    39761
# Name: Customer ID, Length: 49171, dtype: int64>

# %%
Customer_ID_df.describe(include='all')
# Out:
#          Customer ID Gender           Age  Income (USD/Month)
# count   49171.000000  49171  49171.000000        49171.000000
# unique           NaN      2           NaN                 NaN
# top              NaN   Male           NaN                 NaN
# freq             NaN  26562           NaN                 NaN
# mean    28398.252283    NaN     35.363121        15015.631856
# std     17714.137333    NaN     12.599066         8002.208253
# min         1.000000    NaN     18.000000         2000.000000
# 25%     12654.500000    NaN     25.000000         8289.500000
# 50%     27631.000000    NaN     33.000000        14656.000000
# 75%     43284.500000    NaN     42.000000        21035.000000
# max     60000.000000    NaN     65.000000        35000.000000

# %% [markdown]
# # Correlation Analysis

# %%
Merged_df= cab_df.merge(Transaction_ID_df, on= 'Transaction ID').merge(city_df, on = 'City').merge(Customer_ID_df, on ='Customer ID')
Merged_df.head(10)
# Out:
#    Transaction ID Date of Travel     Company        City  KM Travelled  \
# 0        10000011     2016-01-08    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-21  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-23  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-06    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-21  Yellow Cab  ATLANTA GA         36.38
# 5        10324737     2018-05-04  Yellow Cab  ATLANTA GA          6.18
# 6        10395626     2018-10-27    Pink Cab  ATLANTA GA         13.39
# 7        10000013     2016-01-02    Pink Cab  ATLANTA GA          9.04
# 8        10079404     2016-09-21  Yellow Cab  ATLANTA GA         39.60
# 9        10186994     2017-06-23  Yellow Cab  ATLANTA GA         18.19
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode  Population  Users  \
# 0         370.95      313.6350        29290         Card      814885  24701
# 1         598.70      317.4228        29290         Cash      814885  24701
# 2         792.05      597.4020        29290         Card      814885  24701
# 3         358.52      334.8540        27703         Card      814885  24701
# 4         721.10      467.1192        27703         Card      814885  24701
# 5         138.40       87.5088        27703         Cash      814885  24701
# 6         167.03      141.9340        27703         Card      814885  24701
# 7         125.20       97.6320        28712         Cash      814885  24701
# 8         704.30      494.2080        28712         Card      814885  24701
# 9         365.63      246.6564        28712         Card      814885  24701
#
#   Gender  Age  Income (USD/Month)
# 0   Male   28               10813
# 1   Male   28               10813
# 2   Male   28               10813
# 3   Male   27                9237
# 4   Male   27                9237
# 5   Male   27                9237
# 6   Male   27                9237
# 7   Male   53               11242
# 8   Male   53               11242
# 9   Male   53               11242

# %%
Merged_df.isnull()
# Out:
#         Transaction ID  Date of Travel  Company   City  KM Travelled  \
# 0                False           False    False  False         False
# 1                False           False    False  False         False
# 2                False           False    False  False         False
# 3                False           False    False  False         False
# 4                False           False    False  False         False
# ...                ...             ...      ...    ...           ...
# 359387           False           False    False  False         False
# 359388           False           False    False  False         False
# 359389           False           False    False  False         False
# 359390           False           False    False  False         False
# 359391           False           False    False  False         False
#
#         Price Charged  Cost of Trip  Customer ID  Payment_Mode  Population  \
# 0               False         False        False         False       False
# 1               False         False        False         False       False
# 2               False         False        False         False       False
# 3               False         False        False         False       False
# 4               False         False        False         False       False
# ...               ...           ...          ...           ...         ...
# 359387          False         False        False         False       False
# 359388          False         False        False         False       False
# 359389          False         False        False         False       False
# 359390          False         False        False         False       False
# 359391          False         False        False         False       False
#
#         Users  Gender    Age  Income (USD/Month)
# 0       False   False  False               False
# 1       False   False  False               False
# 2       False   False  False               False
# 3       False   False  False               False
# 4       False   False  False               False
# ...       ...     ...    ...                 ...
# 359387  False   False  False               False
# 359388  False   False  False               False
# 359389  False   False  False               False
# 359390  False   False  False               False
# 359391  False   False  False               False
#
# [359392 rows x 14 columns]

# %%
Merged_df.dtypes
# Out:
# Transaction ID                 int64
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Customer ID                    int64
# Payment_Mode                category
# Population                     int64
# Users                          int64
# Gender                      category
# Age                            int64
# Income (USD/Month)             int64
# dtype: object

# %% [markdown]
# profile = ProfileReport(Merged_df,title="Carb Merged Data Profile")
# profile.to_widgets()

# %% [markdown]
# profile = ProfileReport(Merged_df,title="Carb Merged Data Profile")
# profile.to_widgets()

# %% [markdown]
# ## Correlation

# %%
Merged_df.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#          Customer ID    Population          Users            Age  \
# count  359392.000000  3.593920e+05  359392.000000  359392.000000
# mean    19191.652115  3.132198e+06  158365.582267      35.336705
# std     21012.412463  3.315194e+06  100850.051020      12.594234
# min         1.000000  2.489680e+05    3643.000000      18.000000
# 25%      2705.000000  6.712380e+05   80021.000000      25.000000
# 50%      7459.000000  1.595037e+06  144132.000000      33.000000
# 75%     36078.000000  8.405837e+06  302149.000000      42.000000
# max     60000.000000  8.405837e+06  302149.000000      65.000000
#
#        Income (USD/Month)
# count       359392.000000
# mean         15048.822937
# std           7969.409482
# min           2000.000000
# 25%           8424.000000
# 50%          14685.000000
# 75%          21035.000000
# max          35000.000000

# %%
Merged_df.corr(method ='pearson')
# Out:
#                     Transaction ID  KM Travelled  Price Charged  Cost of Trip  \
# Transaction ID            1.000000     -0.001429      -0.052902     -0.003462
# KM Travelled             -0.001429      1.000000       0.835753      0.981848
# Price Charged            -0.052902      0.835753       1.000000      0.859812
# Cost of Trip             -0.003462      0.981848       0.859812      1.000000
# Customer ID              -0.016912      0.000389      -0.177324      0.003077
# Population                0.023868     -0.002311       0.326589      0.015108
# Users                     0.013526     -0.000428       0.281061      0.023628
# Age                      -0.001267     -0.000369      -0.003084     -0.000189
# Income (USD/Month)       -0.001570     -0.000544       0.003228     -0.000633
#
#                     Customer ID  Population     Users       Age  \
# Transaction ID        -0.016912    0.023868  0.013526 -0.001267
# KM Travelled           0.000389   -0.002311 -0.000428 -0.000369
# Price Charged         -0.177324    0.326589  0.281061 -0.003084
# Cost of Trip           0.003077    0.015108  0.023628 -0.000189
# Customer ID            1.000000   -0.647052 -0.610742 -0.004735
# Population            -0.647052    1.000000  0.915490 -0.009002
# Users                 -0.610742    0.915490  1.000000 -0.005906
# Age                   -0.004735   -0.009002 -0.005906  1.000000
# Income (USD/Month)    -0.013608    0.011868  0.010464  0.003907
#
#                     Income (USD/Month)
# Transaction ID               -0.001570
# KM Travelled                 -0.000544
# Price Charged                 0.003228
# Cost of Trip                 -0.000633
# Customer ID                  -0.013608
# Population                    0.011868
# Users                         0.010464
# Age                           0.003907
# Income (USD/Month)            1.000000

# %%
Merged_df.corr().style.background_gradient(cmap='RdYlGn', axis=None)
# Out:
# <style type="text/css">
# #T_10383_row0_col0, #T_10383_row1_col1, #T_10383_row2_col2, #T_10383_row3_col3, #T_10383_row4_col4, #T_10383_row5_col5, #T_10383_row6_col6, #T_10383_row7_col7, #T_10383_row8_col8 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_10383_row0_col1, #T_10383_row0_col3, #T_10383_row0_col7, #T_10383_row0_col8, #T_10383_row1_col0, #T_10383_row1_col4, #T_10383_row1_col5, #T_10383_row1_col6, #T_10383_row1_col7, #T_10383_row1_col8, #T_10383_row2_col7, #T_10383_row3_col0, #T_10383_row3_col7, #T_10383_row3_col8, #T_10383_row4_col1, #T_10383_row5_col1, #T_10383_row6_col1, #T_10383_row7_col0, #T_10383_row7_col1, #T_10383_row7_col2, #T_10383_row7_col3, #T_10383_row8_col0, #T_10383_row8_col1, #T_10383_row8_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_10383_row0_col2, #T_10383_row2_col0 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_10383_row0_col4, #T_10383_row4_col0 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_10383_row0_col5, #T_10383_row3_col6, #T_10383_row5_col0, #T_10383_row6_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_10383_row0_col6, #T_10383_row3_col5, #T_10383_row5_col3, #T_10383_row5_col8, #T_10383_row6_col0, #T_10383_row6_col8, #T_10383_row8_col5, #T_10383_row8_col6 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_10383_row1_col2, #T_10383_row2_col1 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_10383_row1_col3, #T_10383_row3_col1 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_10383_row2_col3, #T_10383_row3_col2 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_10383_row2_col4, #T_10383_row4_col2 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_10383_row2_col5, #T_10383_row5_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_10383_row2_col6, #T_10383_row6_col2 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_10383_row2_col8, #T_10383_row3_col4, #T_10383_row4_col3, #T_10383_row7_col8, #T_10383_row8_col2, #T_10383_row8_col7 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_10383_row4_col5, #T_10383_row5_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_10383_row4_col6, #T_10383_row6_col4 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_10383_row4_col7, #T_10383_row5_col7, #T_10383_row6_col7, #T_10383_row7_col4, #T_10383_row7_col5, #T_10383_row7_col6 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_10383_row4_col8, #T_10383_row8_col4 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_10383_row5_col6, #T_10383_row6_col5 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_10383">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10383_level0_col0" class="col_heading level0 col0" >Transaction ID</th>
#       <th id="T_10383_level0_col1" class="col_heading level0 col1" >KM Travelled</th>
#       <th id="T_10383_level0_col2" class="col_heading level0 col2" >Price Charged</th>
#       <th id="T_10383_level0_col3" class="col_heading level0 col3" >Cost of Trip</th>
#       <th id="T_10383_level0_col4" class="col_heading level0 col4" >Customer ID</th>
#       <th id="T_10383_level0_col5" class="col_heading level0 col5" >Population</th>
#       <th id="T_10383_level0_col6" class="col_heading level0 col6" >Users</th>
#       <th id="T_10383_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_10383_level0_col8" class="col_heading level0 col8" >Income (USD/Month)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10383_level0_row0" class="row_heading level0 row0" >Transaction ID</th>
#       <td id="T_10383_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_10383_row0_col1" class="data row0 col1" >-0.001429</td>
#       <td id="T_10383_row0_col2" class="data row0 col2" >-0.052902</td>
#       <td id="T_10383_row0_col3" class="data row0 col3" >-0.003462</td>
#       <td id="T_10383_row0_col4" class="data row0 col4" >-0.016912</td>
#       <td id="T_10383_row0_col5" class="data row0 col5" >0.023868</td>
#       <td id="T_10383_row0_col6" class="data row0 col6" >0.013526</td>
#       <td id="T_10383_row0_col7" class="data row0 col7" >-0.001267</td>
#       <td id="T_10383_row0_col8" class="data row0 col8" >-0.001570</td>
#     </tr>
#     <tr>
#       <th id="T_10383_level0_row1" class="row_heading level0 row1" >KM Travelled</th>
#       <td id="T_10383_row1_col0" class="data row1 col0" >-0.001429</td>
#       <td id="T_10383_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_10383_row1_col2" class="data row1 col2" >0.835753</td>
#       <td id="T_10383_row1_col3" class="data row1 col3" >0.981848</td>
#       <td id="T_10383_row1_col4" class="data row1 col4" >0.000389</td>
#       <td id="T_10383_row1_col5" class="data row1 col5" >-0.002311</td>
#       <td id="T_10383_row1_col6" class="data row1 col6" >-0.000428</td>
#       <td id="T_10383_row1_col7" class="data row1 col7" >-0.000369</td>
#       <td id="T_10383_row1_col8" class="data row1 col8" >-0.000544</td>
#     </tr>
#     <tr>
#       <th id="T_10383_level0_row2" class="row_heading level0 row2" >Price Charged</th>
#       <td id="T_10383_row2_col0" class="data row2 col0" >-0.052902</td>
#       <td id="T_10383_row2_col1" class="data row2 col1" >0.835753</td>
#       <td id="T_10383_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_10383_row2_col3" class="data row2 col3" >0.859812</td>
#       <td id="T_10383_row2_col4" class="data row2 col4" >-0.177324</td>
#       <td id="T_10383_row2_col5" class="data row2 col5" >0.326589</td>
#       <td id="T_10383_row2_col6" class="data row2 col6" >0.281061</td>
#       <td id="T_10383_row2_col7" class="data row2 col7" >-0.003084</td>
#       <td id="T_10383_row2_col8" class="data row2 col8" >0.003228</td>
#     </tr>
#     <tr>
#       <th id="T_10383_level0_row3" class="row_heading level0 row3" >Cost of Trip</th>
#       <td id="T_10383_row3_col0" class="data row3 col0" >-0.003462</td>
#       <td id="T_10383_row3_col1" class="data row3 col1" >0.981848</td>
#       <td id="T_10383_row3_col2" class="data row3 col2" >0.859812</td>
#       <td id="T_10383_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_10383_row3_col4" class="data row3 col4" >0.003077</td>
#       <td id="T_10383_row3_col5" class="data row3 col5" >0.015108</td>
#       <td id="T_10383_row3_col6" class="data row3 col6" >0.023628</td>
#       <td id="T_10383_row3_col7" class="data row3 col7" >-0.000189</td>
#       <td id="T_10383_row3_col8" class="data row3 col8" >-0.000633</td>
#     </tr>
#     <tr>
#       <th id="T_10383_level0_row4" class="row_heading level0 row4" >Customer ID</th>
#       <td id="T_10383_row4_col0" class="data row4 col0" >-0.016912</td>
#       <td id="T_10383_row4_col1" class="data row4 col1" >0.000389</td>
#       <td id="T_10383_row4_col2" class="data row4 col2" >-0.177324</td>
#       <td id="T_10383_row4_col3" class="data row4 col3" >0.003077</td>
#       <td id="T_10383_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_10383_row4_col5" class="data row4 col5" >-0.647052</td>
#       <td id="T_10383_row4_col6" class="data row4 col6" >-0.610742</td>
#       <td id="T_10383_row4_col7" class="data row4 col7" >-0.004735</td>
#       <td id="T_10383_row4_col8" class="data row4 col8" >-0.013608</td>
#     </tr>
#     <tr>
#       <th id="T_10383_level0_row5" class="row_heading level0 row5" >Population</th>
#       <td id="T_10383_row5_col0" class="data row5 col0" >0.023868</td>
#       <td id="T_10383_row5_col1" class="data row5 col1" >-0.002311</td>
#       <td id="T_10383_row5_col2" class="data row5 col2" >0.326589</td>
#       <td id="T_10383_row5_col3" class="data row5 col3" >0.015108</td>
#       <td id="T_10383_row5_col4" class="data row5 col4" >-0.647052</td>
#       <td id="T_10383_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_10383_row5_col6" class="data row5 col6" >0.915490</td>
#       <td id="T_10383_row5_col7" class="data row5 col7" >-0.009002</td>
#       <td id="T_10383_row5_col8" class="data row5 col8" >0.011868</td>
#     </tr>
#     <tr>
#       <th id="T_10383_level0_row6" class="row_heading level0 row6" >U

# %% [markdown]
# ### Observations:
# Highest Correlation exist between:
#
#
#                                    KM Travelled and Cost of Trip= '0.981848',
#                                    Cost of Trip and Price Charged= '0.835753', and
#                                    KM Travelled and Price Charged= '0.835753'
# Followed by:
#
#                                    Customer_ID and the Price Charged

# %% [markdown]
# ### Graphical Correlation Analysis

# %% [markdown]
# #Merged_df[['KM Travelled', 'Price Charged', 'Cost of Trip','Age','Income (USD/Month)']].plot.hist(alpha=0.5);
# from pandas.plotting import scatter_matrix
# scatter_matrix(Merged_df[['KM Travelled','Price Charged','Cost of Trip','Age','Income (USD/Month)' ]],figsize=(10, 10),);

# %% [markdown]
# sns.pairplot(Merged_df, hue='Company', height=1.5)

# %% [markdown]
# ## 3. Data Examination
# ###  Outlier Identification

# %% [markdown]
#
# fig = plt.figure(figsize =(7, 10))
# #plt.rcParams["figure.autolayout"] = True
# Merged_boxplot= Merged_df.boxplot(column=['KM Travelled', 'Price Charged', 'Cost of Trip','Age','Income (USD/Month)'])
# #price_charged has outliers

# %% [markdown]
# Merged_df.hist()
# fig = plt.figure(figsize =(10, 10))

# %% [markdown]
# ### Price Charged

# %% [markdown]
# Price_charged_scatter = Merged_df.plot.scatter(y='Price Charged',
# ...                   x='Date of Travel',
# ...                   c='DarkBlue')
#
# Cost_of_Trip_scatter = Merged_df.plot.scatter(y='Cost of Trip',
# ...                   x='Date of Travel',
# ...                   c='Red')

# %% [markdown]
#     The numerical histograms for 'Date of Travel', KM Travelled, Price Charged, Cost of Trip, Age and Income(USD/Month), are right skewed thus mean> median > mode.
#     Outliers cannot be eliminated using z value but Interquartile range.

# %% [markdown]
# ##### Removing Outliers

# %%
upper_limit = Merged_df["Price Charged"].mean() + 3*Merged_df["Price Charged"].std()

print("Upper limit:", upper_limit)

lower_limit = Merged_df["Price Charged"].mean()-3*Merged_df["Price Charged"].std()

print("lower limit:", lower_limit)

Merged_df["Price Charged"] = np.where(Merged_df["Price Charged"] > upper_limit,

    upper_limit,

    np.where (

       Merged_df["Price Charged"] < lower_limit,

       lower_limit,

       Merged_df["Price Charged"]

   )

)
# Out:
# Upper limit: 1246.5800455975784
# lower limit: -399.6934230795479

# %% [markdown]
# Outliers[]
# MergedOut_df=Merged_df
# Outliers[]=Merged_df["Price Charged"]-MergedOut_df["Price Charged"]
# Outliers

# %%
Merged_df.describe()[["Price Charged"]]
# Out:
#        Price Charged
# count  359392.000000
# mean      422.281094
# std       270.344818
# min        15.600000
# 25%       206.437500
# 50%       386.360000
# 75%       583.660000
# max      1246.580046

# %% [markdown]
# Price_charged_scatter = Merged_df.plot.scatter(x='Date of Travel',
# ...                   y= 'Price Charged',
# ...                   c='DarkBlue')

# %%
l_df = pd.DataFrame(Merged_df, columns=["Users", "Price Charged", "KM Travelled","Date of Travel"])
 
l_df.plot(x="Date of Travel", y=["Users", "Price Charged", "KM Travelled"], kind="bar", figsize=(9, 8))
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ### KM Travelled

# %% [markdown]
# ####  Payment Mode

# %%
plt.figure(figsize = (16, 9))
ax = sns.countplot(x="Company", hue="Payment_Mode", data=Transaction_ID_df)
plt.title('Payment Mode in both companies', fontsize=19)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 2
#       1 plt.figure(figsize = (16, 9))
# ----> 2 ax = sns.countplot(x="Company", hue="Payment_Mode", data=Transaction_ID_df)
#       3 plt.title('Payment Mode in both companies', fontsize=19)
#       4 plt.show()
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Company'

# %% [markdown]
# #### Gender

# %% [markdown]
# ## City

# %%
no_of_users = (city_df['Users'] /city_df['Population']) * 100 
cities = city_df['City']
from random import randint

colors = []
n = 16

for i in range(n):
    colors.append('#%06X' % randint(0, 0xFFFFFF))
plt.figure(figsize = (16, 9))
plt.bar(cities, no_of_users, edgecolor='black', color = colors)
plt.gcf().autofmt_xdate()
plt.title('User Percentage of Population by Cities')
plt.ylabel('Percentage (%)')
plt.xlabel('Cities')
plt.show()

# %%
plot = city_df.plot.pie(subplots=True, figsize=(5, 5))

# %%
sns.countplot(data=df, x="class", hue="alive")

# %%
Merged_df.plot(y='Population', x='Users', kind='pie', labels=Merged_df['City'], title='Population by City', subplots=True)
plt.show()

# %% [markdown]
# # Hypothesis and  Investigate

# %% [markdown]
# ###### Hypothesis 1: Do users prefer cash or Card Payments?

# %%
H0: Cab users generally prefer using Card Payments to Cash Payments.
H1: Cab users generally do notprefer using Card Payments to Cash Payments.
